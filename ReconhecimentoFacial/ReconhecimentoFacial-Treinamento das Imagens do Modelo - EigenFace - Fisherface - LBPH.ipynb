# %%
import pandas as pd

# %%
df = pd.read_csv('c:\\Users\\ricardo.rlima\\ReconhecimentoFacial\\dados\\datafone2.csv')

# %%
df
# Out:
#      matricula                                      nome  \
# 0       346004                   Abel Oliveira Maracaipe
# 1       296457                   Abilino Leniel de Jesus
# 2       354414          Abinel Santiago Cerqueira Junior
# 3       355631          Abraao Lenon Moreira de Oliveira
# 4       264466                 Abraao Martins de Andrade
# 5       245356                  Adaide Deoliveira Santos
# 6       235415                  Adalberto de Sousa Filho
# 7       307807         Adalberto Tadeu Alves de Oliveira
# 8       288845                  Adalton Pereira da Silva
# 9       348058                    Adauto Soares da Silva
# 10      356093                    Adeilson Jose da Silva
# 11      290122  Adelia Maria Mangelli Ferreira Fernandes
# 12      348988                Adelson Francisco da Silva
# 13      222658               Ademilda Lins Serafim Tello
# 14      302511                         Ademildes Brandao
# 15      296317                     Adenildo Santos Sousa
# 16      289922                 Adilson da Silva Severino
# 17      275247                            Adilson Freire
# 18      333441        Adilson Lima de Santa Maria Junior
# 19      338940                     Adilson Oliveira Cruz
# 20      332429                  Adilton Ribeiro de Souza
# 21      266060                     Adir Bernardo Batista
# 22      309150            Adonias Carneiro Arruda Junior
# 23      350346                   Adonis Tavares da Silva
# 24      232394             Adriana Aparecida Dias Cabral
# 25      341550                  Adriana Barbosa da Silva
# 26      308153              Adriana Barbosa Lima e Silva
# 27      343951                     Adriana Braga Iriarte
# 28      346063                  Adriana da Silva e Silva
# 29      329711                    Adriana Freire Pereira
# ...        ...                                       ...
# 1966    276006               Katia Regina Araujo Ribeiro
# 1967    308072              Katia Verlan Goncalves Roger
# 1968    222810                             Kazuo Ikegami
# 1969    738581                Kelvin Alef de Sales Silva
# 1970    738344          Kelvin Zarur Moreira de Oliveira
# 1971    344745              Kermeson de Oliveira Martins
# 1972    341380                   Khaue Rezende Rodrigues
# 1973    305081      Kivania Ferreira Monteiro dos Santos
# 1974    294004                    Kiyoko Maeda Marsoleki
# 1975    330299                      Kleber Motta Azevedo
# 1976    343323                   Kleber Ribeiro Carneiro
# 1977   E915045                   Laercio Cardoso Batista
# 1978    212326                            Laercio Soares
# 1979    352985                     Laerte Bernardi Filho
# 1980    350222                              Laerte Lopes
# 1981    328588               Laide Elaine Santana Santos
# 1982    269450                     Lais Torres Goncalves
# 1983    345288                       Larissa Bessa Bueno
# 1984    330094                   Laudecir Pereira Junior
# 1985    266477                Laudicea Guedes dos Santos
# 1986    300497              Laura Maria Macedo de Mattos
# 1987    309044               Laurica Nunes do Nascimento
# 1988    289370                       Laurinda Maia Lopes
# 1989    241415                    Lauro Amaral Guerreiro
# 1990    355747                Layenis Gonçalves Sobrinho
# 1991    275735           Lazaro Jose Vieira de Sant Anna
# 1992    344478            Leandro Afonso Franca Cordeiro
# 1993    354279                   Leandro Brandao Marques
# 1994    352926           Leandro Cianconi de Paiva Rodas
# 1995    346187                  Leandro de Castro Campos
#
#                           cargo predio   ddd ramal setor
# 0                Analista de TI     CF  (61)  3448  D2GO
# 1              Assistente de TI     SP  (11)  5399  D3OS
# 2                Analista de TI     AR  (21)  7443  SVPI
# 3                Analista de TI     RN  (84)  2927  DMP5
# 4              Assistente de TI     CE  (85)  1705  DMP2
# 5              Assistente de TI     SP  (11)  5502  SEAC
# 6              Assistente de TI     CE  (85)  1818  SEAJ
# 7              Assistente de TI     SP  (11)  5511  SEAC
# 8              Assistente de TI     CV  (21)  6540  SVIC
# 9     Analista de Processamento     CF  (61)  3485  D2OS
# 10               Analista de TI     SD  (61)  3182   DIT
# 11               Analista de TI     MG  (31)  4535  DVTS
# 12               Analista de TI     AR  (21)  8195  DIAT
# 13             Assistente de TI     SP  (11)  5147  SSPP
# 14             Assistente de TI     MG  (31)  4515  SEAF
# 15             Assistente de TI     AR  (21)  1231  DVTS
# 16             Assistente de TI     AR  (21)  8783  DCSA
# 17             Assistente de TI     AR  (21)  7711  SVCP
# 18               Analista de TI     SC  (48)  4997  COGD
# 19               Analista de TI     ES  (27)  5618  UDRJ
# 20               Analista de TI     CE  (85)  1707  UDCE
# 21             Assistente de TI     CF  (61)  3311  D2SS
# 22             Assistente de TI     MS  (67)  2342  DMST
# 23               Analista de TI     RN  (84)  2903  UDRN
# 24             Assistente de TI     SD  (61)  1668  COIG
# 25               Analista de TI     CE  (85)  1708  DMP2
# 26             Assistente de TI     PI  (86)  1131  SPIA
# 27               Analista de TI     AR  (21)  7971  DICT
# 28               Analista de TI     AR  (21)  8173  SVES
# 29               Analista de TI     SD  (61)  3258  DINI
# ...                         ...    ...   ...   ...   ...
# 1966             Analista de TI     AR  (21)  7187  SG1Q
# 1967           Assistente de TI     BA  (71)  4275  DBAA
# 1968           Assistente de TI     SP  (11)  5029  DSPT
# 1969                 Estagiario     CE  (85)  1761  1904
# 1970                 Estagiario     MS  (67)     -  DMST
# 1971             Analista de TI     CE  (85)  1730  1939
# 1972             Analista de TI     SC  (48)  4739  COGD
# 1973           Assistente de TI     PB  (83)  2147  DVTS
# 1974           Assistente de TI     PR  (41)  1694  DPRT
# 1975           Assistente de TI     CV  (21)  6454  D1IP
# 1976             Analista de TI     CE  (85)  1794  DMP2
# 1977               Terceirizado     CV  (21)     -  D1IP
# 1978           Assistente de TI     SC  (48)  4946  DSCT
# 1979             Analista de TI     SP  (11)  5414  D3SS
# 1980             Analista de TI     SP  (11)  5146  SSPL
# 1981             Analista de TI     SE  (79)  1506  UDRJ
# 1982           Assistente de TI     AR  (21)  8015  DEGS
# 1983             Analista de TI     AR  (21)  8118  DIRE
# 1984             Analista de TI     CV  (21)  6283  D1SS
# 1985           Assistente de TI     PE  (81)  5845  SEBA
# 1986             Analista de TI     SD  (61)  4212  COIG
# 1987           Assistente de TI     GO  (62)  2651  SGOA
# 1988             Analista de TI     AR  (21)  7928  DIGT
# 1989             Analista de TI     RS  (51)  4004  DRST
# 1990             Analista de TI     RN  (84)  2929  SPP5
# 1991           Assistente de TI     AR  (21)  7580  CORS
# 1992             Analista de TI     AR  (21)  8142  UDRJ
# 1993             Analista de TI     AR  (21)  7945  DICI
# 1994             Analista de TI     AR  (21)  8615  DICI
# 1995             Analista de TI     CE  (85)  1847  UDCE
#
# [1996 rows x 7 columns]

# %%
df[['cargo', 'setor']]
# Out:
#                           cargo setor
# 0                Analista de TI  D2GO
# 1              Assistente de TI  D3OS
# 2                Analista de TI  SVPI
# 3                Analista de TI  DMP5
# 4              Assistente de TI  DMP2
# 5              Assistente de TI  SEAC
# 6              Assistente de TI  SEAJ
# 7              Assistente de TI  SEAC
# 8              Assistente de TI  SVIC
# 9     Analista de Processamento  D2OS
# 10               Analista de TI   DIT
# 11               Analista de TI  DVTS
# 12               Analista de TI  DIAT
# 13             Assistente de TI  SSPP
# 14             Assistente de TI  SEAF
# 15             Assistente de TI  DVTS
# 16             Assistente de TI  DCSA
# 17             Assistente de TI  SVCP
# 18               Analista de TI  COGD
# 19               Analista de TI  UDRJ
# 20               Analista de TI  UDCE
# 21             Assistente de TI  D2SS
# 22             Assistente de TI  DMST
# 23               Analista de TI  UDRN
# 24             Assistente de TI  COIG
# 25               Analista de TI  DMP2
# 26             Assistente de TI  SPIA
# 27               Analista de TI  DICT
# 28               Analista de TI  SVES
# 29               Analista de TI  DINI
# ...                         ...   ...
# 1966             Analista de TI  SG1Q
# 1967           Assistente de TI  DBAA
# 1968           Assistente de TI  DSPT
# 1969                 Estagiario  1904
# 1970                 Estagiario  DMST
# 1971             Analista de TI  1939
# 1972             Analista de TI  COGD
# 1973           Assistente de TI  DVTS
# 1974           Assistente de TI  DPRT
# 1975           Assistente de TI  D1IP
# 1976             Analista de TI  DMP2
# 1977               Terceirizado  D1IP
# 1978           Assistente de TI  DSCT
# 1979             Analista de TI  D3SS
# 1980             Analista de TI  SSPL
# 1981             Analista de TI  UDRJ
# 1982           Assistente de TI  DEGS
# 1983             Analista de TI  DIRE
# 1984             Analista de TI  D1SS
# 1985           Assistente de TI  SEBA
# 1986             Analista de TI  COIG
# 1987           Assistente de TI  SGOA
# 1988             Analista de TI  DIGT
# 1989             Analista de TI  DRST
# 1990             Analista de TI  SPP5
# 1991           Assistente de TI  CORS
# 1992             Analista de TI  UDRJ
# 1993             Analista de TI  DICI
# 1994             Analista de TI  DICI
# 1995             Analista de TI  UDCE
#
# [1996 rows x 2 columns]

# %%
while(True):
    if (df['matricula'] == '352233'):
        print('Ricardo Roberto de Lima')
    else:
        print('Não encontrado!')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-98d9cb48af06> in <module>()
#       1 while(True):
# ----> 2     if (df['matricula'] == '352233'):
#       3         print('Ricardo Roberto de Lima')
#       4     else:
#       5         print('Não encontrado!')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1571         raise ValueError("The truth value of a {0} is ambiguous. "
#    1572                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1573                          .format(self.__class__.__name__))
#    1574
#    1575     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import cv2
import os

detectorFace = cv2.CascadeClassifier("haarcascade-frontalface-default.xml")
reconhecedorFace = cv2.face_LBPHFaceRecognizer.create() #cv2.createLBPHFaceRecognizer()
#reconhecedorFace = cv2.face.LBPHFaceRecognizer.create() #cv2.createLBPHFaceRecognizer()
#cv2.createLBPHFaceRecognizer()
#reconhecedorFace = cv2.ACCESS_FAST.LBPHFaceRecognizer_create() #cv2.createLBPHFaceRecognizer()
reconhecedorFace.read("classificadorLBPH.yml")
largura, altura = 220, 220
font = cv2.FONT_HERSHEY_COMPLEX_SMALL
camera = cv2.VideoCapture(0)
dicNomes = {}
def getNome():
    caminhos = [os.path.join('fotos', f) for f in os.listdir('fotos')]

    nId = {}
    for caminhoImagem in caminhos:
        nome = os.path.split(caminhoImagem)[-1].split('.')[0]
        id = os.path.split(caminhoImagem)[-1].split('.')[1]
        nId [str(id)] = nome
        nId[str(-1)] = "Desconhecido"
    return nId


dicNomes = getNome()
while(True):
    conectado, imagem = camera.read()

    imagemCinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
    facesDetectadas = detectorFace.detectMultiScale(imagemCinza, scaleFactor= 1.1, minSize= (200,200))

    for(x, y, l, a) in facesDetectadas:
        imagemFace = cv2.resize(imagemCinza[y:y + a, x:x + l], (largura, altura))
        cv2.rectangle(imagem,(x, y), (x + l, y + a), (0,0,255), 2 )
        id, confianca = reconhecedorFace.predict(imagemFace)

        cv2.putText(imagem,dicNomes[str(id)], (x,y + (a + 30)), font, 2,(0,0,255))
        cv2.putText(imagem, str(confianca), (x, y + (a + 50)), font, 1, (0, 0, 255))
        if id == 1:
            print("Sala liberada, " + dicNomes[str(id)])
        else:
            print("Autenticação negada")
    cv2.imshow('Face', imagem)
    if cv2.waitKey(1) == ord('q'):
        break
        cv2.close()


camera.release()
cv2.destroyAllWindows()
# Out:
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
# Sala liberada, Ricardo Roberto
